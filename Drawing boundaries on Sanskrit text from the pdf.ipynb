# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import pdf2image as pdf
import re
import pytesseract
import os
import PIL

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
pages = pdf.convert_from_path("Sanskrit_Text.pdf",500,poppler_path=r"C:\Users\Akshat Mittu\Desktop\poppler-0.68.0\bin")

# %%
plt.figure(figsize=(10,10))
plt.imshow(pages[4])

# %%
img = cv.imread("sans0.png")
img1 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
#converting to grayscale
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
#applying gaussian blur
blur = cv.GaussianBlur(gray,(3,3),0)
#thresholding to convert into binary
thresholded = cv.adaptiveThreshold(blur,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY_INV,11,9)
#dilate image to connect text contours
kernel = cv.getStructuringElement(cv.MORPH_RECT,(9,1))
dilated = cv.morphologyEx(thresholded,cv.MORPH_CLOSE,kernel)
#get external contours
contours = cv.findContours(dilated,cv.RETR_EXTERNAL,cv.CHAIN_APPROX_SIMPLE)
contours = contours[0] if len(contours)==2 else contours[1]
#draw contours
result = img1.copy()
images = []
texts = []
f = 0
for points in contours:
    x,y,w,h = cv.boundingRect(points)
    text_img = result[y:y + h, x:x + w]
    text = pytesseract.image_to_string(text_img,lang='san+eng')
    text = re.sub("[().:~\n\s?-]","",text)
    if not text.isalpha():
        cv.rectangle(result,(x,y),(x+w,y+h),(0,0,0),1)
        #cv.imwrite('output/page0/boundaries'+str(f)+'.jpg',result)
    texts.append(text)
    images.append(text_img)
    #print(text,text.isalpha())
cv.imwrite('output/page0/boundaries0.jpg',result)
plt.figure(figsize=(10,10))
plt.imshow(result)
plt.axis('off')
# Out:
# (-0.5, 737.5, 796.5, -0.5)

# %%
img = cv.imread("sans.png")
img1 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
#converting to grayscale
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
#applying gaussian blur
blur = cv.GaussianBlur(gray,(3,3),0)
#thresholding to convert into binary
thresholded = cv.adaptiveThreshold(blur,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY_INV,11,9)
#dilate image to connect text contours
kernel = cv.getStructuringElement(cv.MORPH_RECT,(15,1))
dilated = cv.morphologyEx(thresholded,cv.MORPH_CLOSE,kernel)
#get external contours
contours = cv.findContours(dilated,cv.RETR_EXTERNAL,cv.CHAIN_APPROX_SIMPLE)
contours = contours[0] if len(contours)==2 else contours[1]
#draw contours
result = img1.copy()
images = []
texts = []
f = 0
for points in contours:
    x,y,w,h = cv.boundingRect(points)
    text_img = result[y:y + h, x:x + w]
    text = pytesseract.image_to_string(text_img,lang='san+eng')
    text = re.sub("[().:~\n\s?-]","",text)
    if not text.isalpha():
        cv.rectangle(result,(x,y),(x+w,y+h),(0,0,0),1)
#         cv.imwrite('output/page1/boundaries1.jpg',result)
    texts.append(text)
    images.append(text_img)
    #print(text,text.isalpha())
cv.imwrite('output/page1/boundaries1.jpg',result)
plt.figure(figsize=(10,10))
plt.imshow(result)
plt.axis('off')
# Out:
# (-0.5, 865.5, 650.5, -0.5)

# %%
img = cv.imread("sans3.png")
img1 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
#converting to grayscale
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
#applying gaussian blur
blur = cv.GaussianBlur(gray,(3,3),0)
#thresholding to convert into binary
thresholded = cv.adaptiveThreshold(blur,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY_INV,11,9)
#dilate image to connect text contours
kernel = cv.getStructuringElement(cv.MORPH_RECT,(13,1))
dilated = cv.morphologyEx(thresholded,cv.MORPH_CLOSE,kernel)
#get external contours
contours = cv.findContours(dilated,cv.RETR_EXTERNAL,cv.CHAIN_APPROX_SIMPLE)
contours = contours[0] if len(contours)==2 else contours[1]
#draw contours
result = img1.copy()
images = []
texts = []
f = 0
for points in contours:
    x,y,w,h = cv.boundingRect(points)
    text_img = result[y:y + h, x:x + w]
    text = pytesseract.image_to_string(text_img,lang='san+eng')
    text = re.sub("[().:~\n\s?-]","",text)
    if not text.isalpha():
        cv.rectangle(result,(x,y),(x+w,y+h),(0,0,0),1)
#         cv.imwrite('output/page2/boundaries2.jpg',result)
        f+=1
    texts.append(text)
    images.append(text_img)
    #print(text,text.isalpha())
cv.imwrite('output/page2/boundaries2.jpg',result)
plt.figure(figsize=(10,10))
plt.imshow(result)
plt.axis('off')
# Out:
# (-0.5, 749.5, 784.5, -0.5)

# %%
img = cv.imread("sans4.png")
img1 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
#converting to grayscale
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
#applying gaussian blur
blur = cv.GaussianBlur(gray,(5,5),0)
#thresholding to convert into binary
thresholded = cv.adaptiveThreshold(blur,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY_INV,11,9)
#dilate image to connect text contours
kernel = cv.getStructuringElement(cv.MORPH_RECT,(10,1))
dilated = cv.morphologyEx(thresholded,cv.MORPH_CLOSE,kernel)
#get external contours
contours = cv.findContours(dilated,cv.RETR_EXTERNAL,cv.CHAIN_APPROX_SIMPLE)
contours = contours[0] if len(contours)==2 else contours[1]
#draw contours
result = img1.copy()
images = []
texts = []
f = 0
for points in contours:
    x,y,w,h = cv.boundingRect(points)
    text_img = result[y:y + h, x:x + w]
    text = pytesseract.image_to_string(text_img,lang='san+eng')
    text = re.sub("[().:~\n\s?-]","",text)
    if not text.isalpha():
        cv.rectangle(result,(x,y),(x+w,y+h),(0,0,0),1)
        ##cv.imwrite('output/page3/boundaries3.jpg',result)
        f+=1
    texts.append(text)
    images.append(text_img)
    #print(text,text.isalpha())
cv.imwrite('output/page3/boundaries3.jpg',result)
plt.figure(figsize=(10,10))
plt.imshow(result)
plt.axis('off')
# Out:
# (-0.5, 699.5, 781.5, -0.5)

# %%
img = cv.imread("sans2.png")
img1 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
#converting to grayscale
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
#applying gaussian blur
blur = cv.GaussianBlur(gray,(3,3),0)
#thresholding to convert into binary
thresholded = cv.adaptiveThreshold(blur,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY_INV,11,9)
#dilate image to connect text contours
kernel = cv.getStructuringElement(cv.MORPH_RECT,(15,1))
dilated = cv.morphologyEx(thresholded,cv.MORPH_CLOSE,kernel)
#get external contours
contours = cv.findContours(dilated,cv.RETR_EXTERNAL,cv.CHAIN_APPROX_SIMPLE)
contours = contours[0] if len(contours)==2 else contours[1]
#draw contours
result = img1.copy()
images = []
texts = []
f = 0
for points in contours:
    x,y,w,h = cv.boundingRect(points)
    text_img = result[y:y + h, x:x + w]
    text = pytesseract.image_to_string(text_img,lang='san+eng')
    text = re.sub("[().:~\n\s?-]","",text)
    if not text.isalpha():
        cv.rectangle(result,(x,y),(x+w,y+h),(0,0,0),1)
        cv.imwrite('output/page4/boundaries4.jpg',result)
    texts.append(text)
    images.append(text_img)
    #print(text,text.isalpha())
cv.imwrite('output/page4/boundaries4.jpg',result)
plt.figure(figsize=(10,10))
plt.imshow(result)
plt.axis('off')
# Out:
# (-0.5, 832.5, 811.5, -0.5)

# %%
os.mkdir("output")
for i in range(len(pages)):
    os.mkdir("output/page"+str(i))
    a = np.array(pages[i])
    x = cv.cvtColor(a,cv.COLOR_RGB2BGR)
    cv.imwrite("output/page"+str(i)+"/original"+str(i)+".jpg",x)
    
    img = cv.imread("output/page"+str(i)+"/original"+str(i)+".jpg")
    img1 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
    #converting to grayscale
    gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
    #applying gaussian blur
    blur = cv.GaussianBlur(gray,(3,3),0)
    #thresholding to convert into binary
    thresholded = cv.adaptiveThreshold(blur,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY_INV,11,9)
    #dilate image to connect text contours
    kernel = cv.getStructuringElement(cv.MORPH_RECT,(15,1))
    dilated = cv.morphologyEx(thresholded,cv.MORPH_CLOSE,kernel)
    #get external contours
    contours = cv.findContours(dilated,cv.RETR_EXTERNAL,cv.CHAIN_APPROX_SIMPLE)
    contours = contours[0] if len(contours)==2 else contours[1]
    #draw contours
    result = img1.copy()
    images = []
    texts = []
    f = 0
    for points in contours:
        x,y,w,h = cv.boundingRect(points)
        text_img = result[y:y + h, x:x + w]
        text = pytesseract.image_to_string(text_img,lang='san+eng')
        text = re.sub("[().:~\n\s?-]","",text)
        if not text.isalpha():
            cv.rectangle(result,(x,y),(x+w,y+h),(0,0,0),1)
        cv.imwrite("output/page"+str(i)+"/box"+str(f)+".jpg",text_img)
        f+=1
        #print(text,text.isalpha())
    plt.figure(figsize=(10,10))
    plt.imshow(result)
    plt.axis('off')

# %%
contours[0]
# Out:
# array([[275, 777]], dtype=int32)

# %%
for i in contours:
    print(i)
# Out:
# [[275 777]]
# [[276 776]]
# [[294 776]]
# [[295 777]]
# [[294 778]]
# [[276 778]]

# %%
len(contours)
# Out:
# 6

# %%
images = os.listdir('output/page1')

# %%
images
# Out:
# ['box0.jpg',
#  'box1.jpg',
#  'box10.jpg',
#  'box11.jpg',
#  'box12.jpg',
#  'box13.jpg',
#  'box14.jpg',
#  'box15.jpg',
#  'box16.jpg',
#  'box17.jpg',
#  'box18.jpg',
#  'box19.jpg',
#  'box2.jpg',
#  'box20.jpg',
#  'box21.jpg',
#  'box22.jpg',
#  'box23.jpg',
#  'box24.jpg',
#  'box25.jpg',
#  'box26.jpg',
#  'box27.jpg',
#  'box28.jpg',
#  'box3.jpg',
#  'box4.jpg',
#  'box5.jpg',
#  'box6.jpg',
#  'box7.jpg',
#  'box8.jpg',
#  'box9.jpg',
#  'original1.jpg']

# %%
plt.imshow(text_img)

# %%
page4 = dict()
images = os.listdir('output/page4')
images.pop(-1)
images.pop(0)
# Out:
# 'boundaries4.jpg'

# %%
images
# Out:
# ['box0.jpg',
#  'box1.jpg',
#  'box10.jpg',
#  'box14.jpg',
#  'box15.jpg',
#  'box16.jpg',
#  'box18.jpg',
#  'box22.jpg',
#  'box25.jpg',
#  'box3.jpg',
#  'box30.jpg',
#  'box31.jpg',
#  'box33.jpg',
#  'box34.jpg',
#  'box35.jpg',
#  'box38.jpg',
#  'box41.jpg',
#  'box42.jpg',
#  'box43.jpg',
#  'box49.jpg',
#  'box5.jpg',
#  'box52.jpg',
#  'box53.jpg',
#  'box55.jpg',
#  'box58.jpg',
#  'box60.jpg',
#  'box62.jpg',
#  'box66.jpg',
#  'box7.jpg',
#  'box71.jpg',
#  'box72.jpg',
#  'box8.jpg',
#  'box9.jpg']

# %%
image1 = cv.imread(images[0])

# %%
image = cv.imread('output/page0/box0.jpg')

# %%
image.shape
# Out:
# (15, 159, 3)

# %%
for i in images:
    print(cv.imread('output/page4/'+i).shape,i)
# Out:
# (17, 182, 3) box0.jpg
# (14, 125, 3) box1.jpg
# (22, 215, 3) box10.jpg
# (23, 221, 3) box14.jpg
# (19, 62, 3) box15.jpg
# (21, 37, 3) box16.jpg
# (22, 348, 3) box18.jpg
# (5, 15, 3) box22.jpg
# (22, 313, 3) box25.jpg
# (17, 163, 3) box3.jpg
# (23, 347, 3) box30.jpg
# (23, 315, 3) box31.jpg
# (19, 137, 3) box33.jpg
# (21, 56, 3) box34.jpg
# (18, 50, 3) box35.jpg
# (23, 310, 3) box38.jpg
# (23, 297, 3) box41.jpg
# (19, 62, 3) box42.jpg
# (18, 54, 3) box43.jpg
# (21, 390, 3) box49.jpg
# (16, 104, 3) box5.jpg
# (21, 193, 3) box52.jpg
# (18, 50, 3) box53.jpg
# (23, 325, 3) box55.jpg
# (21, 274, 3) box58.jpg
# (14, 78, 3) box60.jpg
# (18, 54, 3) box62.jpg
# (24, 440, 3) box66.jpg
# (21, 86, 3) box7.jpg
# (21, 173, 3) box71.jpg
# (28, 168, 3) box72.jpg
# (19, 264, 3) box8.jpg
# (28, 252, 3) box9.jpg

# %%
page3 = dict()

# %%
for i in images:
    image = cv.imread('output/page4/'+i)
    x,y = 0,0
    h,w,c = image.shape 
    n = i.split('.')[0]
    page4[n] = dict()
    page4[n]['top_left'] = [x,y]
    page4[n]['top_right'] = [x,y+h]
    page4[n]['bottom_left'] = [x+w,y]
    page4[n]['bottom_right'] = [x+h,y+w]

# %%
page4
# Out:
# {'box0': {'top_left': [0, 0],
#   'top_right': [0, 17],
#   'bottom_left': [182, 0],
#   'bottom_right': [17, 182]},
#  'box1': {'top_left': [0, 0],
#   'top_right': [0, 14],
#   'bottom_left': [125, 0],
#   'bottom_right': [14, 125]},
#  'box10': {'top_left': [0, 0],
#   'top_right': [0, 22],
#   'bottom_left': [215, 0],
#   'bottom_right': [22, 215]},
#  'box14': {'top_left': [0, 0],
#   'top_right': [0, 23],
#   'bottom_left': [221, 0],
#   'bottom_right': [23, 221]},
#  'box15': {'top_left': [0, 0],
#   'top_right': [0, 19],
#   'bottom_left': [62, 0],
#   'bottom_right': [19, 62]},
#  'box16': {'top_left': [0, 0],
#   'top_right': [0, 21],
#   'bottom_left': [37, 0],
#   'bottom_right': [21, 37]},
#  'box18': {'top_left': [0, 0],
#   'top_right': [0, 22],
#   'bottom_left': [348, 0],
#   'bottom_right': [22, 348]},
#  'box22': {'top_left': [0, 0],
#   'top_right': [0, 5],
#   'bottom_left': [15, 0],
#   'bottom_right': [5, 15]},
#  'box25': {'top_left': [0, 0],
# ...

# %%
d = 'box0.jpg'
print(d.split('.')[0])
# Out:
# box0

# %%
import json

# %%
len(page4)
# Out:
# 33

# %%
json_ob = json.dumps(page4,indent=4)

# %%
json_ob
# Out:
# '{\n    "box0": {\n        "top_left": [\n            0,\n            0\n        ],\n        "top_right": [\n            0,\n            17\n        ],\n        "bottom_left": [\n            182,\n            0\n        ],\n        "bottom_right": [\n            17,\n            182\n        ]\n    },\n    "box1": {\n        "top_left": [\n            0,\n            0\n        ],\n        "top_right": [\n            0,\n            14\n        ],\n        "bottom_left": [\n            125,\n            0\n        ],\n        "bottom_right": [\n            14,\n            125\n        ]\n    },\n    "box10": {\n        "top_left": [\n            0,\n            0\n        ],\n        "top_right": [\n            0,\n            22\n        ],\n        "bottom_left": [\n            215,\n            0\n        ],\n        "bottom_right": [\n            22,\n            215\n        ]\n    },\n    "box14": {\n        "top_left": [\n            0,\n            0\n        ],\n        "to
# ...

# %%
with open('output/page4/p4_json.json','w') as file:
    file.write(json_ob)
